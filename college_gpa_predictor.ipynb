# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('sat_gpa_v1.csv')
data
# Out:
#      sat_sum  fy_gpa
# 0       1270    3.18
# 1       1220    3.33
# 2       1160    3.25
# 3        950    2.42
# 4       1070    2.63
# ..       ...     ...
# 995     1000    2.19
# 996     1080    1.50
# 997     1140    3.17
# 998     1200    1.94
# 999      930    2.38
#
# [1000 rows x 2 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 2 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   sat_sum  1000 non-null   int64
#  1   fy_gpa   1000 non-null   float64
# dtypes: float64(1), int64(1)
# memory usage: 15.8 KB

# %%
scatter = sns.scatterplot(data=data, x='sat_sum', y='fy_gpa')
scatter.set_xlabel('SAT Summary')
scatter.set_ylabel('Fiscal Year GPA')
# Out:
# Text(0, 0.5, 'Fiscal Year GPA')

# %%
lmplot = sns.lmplot(data=data, x='sat_sum', y='fy_gpa')
lmplot.set(xlabel='SAT Summary', ylabel='Fiscal Year GPA')

# %% [markdown]
# ### Scatter Plot for the analysis, here we see a weak correlation between SAT scores and Fiscal Year GPA. This supports a theory that there are people who just take tests better than others.

# %%
## regression model
import statsmodels.api as sm

# %%
model = sm.OLS(data['sat_sum'], sm.add_constant(data['fy_gpa'])).fit()
print(model.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                sat_sum   R-squared:                       0.212
# Model:                            OLS   Adj. R-squared:                  0.211
# Method:                 Least Squares   F-statistic:                     268.3
# Date:                Mon, 15 May 2023   Prob (F-statistic):           1.39e-53
# Time:                        21:03:57   Log-Likelihood:                -6261.4
# No. Observations:                1000   AIC:                         1.253e+04
# Df Residuals:                     998   BIC:                         1.254e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const        814.2075     13.965     58.304      0.000     786.804     841.611
# ...

# %% [markdown]
# ### OLS Model for the linear regression

# %% [markdown]
# #### according to this regression model...

# %%
lmplot = sns.lmplot(data=data, x='sat_sum', y='fy_gpa', scatter_kws={'alpha': 0.3, 'color': 'orange'},
                    line_kws={'alpha': 0.7, 'color':'lightblue'})
lmplot.set(xlabel='SAT Summary', ylabel='Fiscal Year GPA')

# %%
### Extended Challenge

# %%
data.corr()
# Out:
#           sat_sum    fy_gpa
# sat_sum  1.000000  0.460281
# fy_gpa   0.460281  1.000000

# %%
from pandas_profiling import ProfileReport
# Out:
# /var/folders/j1/p24gk4zn09l83n0_hh3m02gc0000gn/T/ipykernel_52434/2274191625.py:1: DeprecationWarning: `import pandas_profiling` is going to be deprecated by April 1st. Please use `import ydata_profiling` instead.
#   from pandas_profiling import ProfileReport

# %%
profile = ProfileReport(data, title='Pandas Profiling Report')
profile.to_notebook_iframe()# profiler report
# Out:
# Summarize dataset:   0%|          | 0/5 [00:00<?, ?it/s]
